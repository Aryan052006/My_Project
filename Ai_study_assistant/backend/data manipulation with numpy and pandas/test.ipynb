# %%
import pandas as pd

# %%
df=pd.read_csv('data2.csv')
##Fetch first 5 rows
df.head(5)
# Out:
#   conceptType                               conceptUri  \
# 0  SkillGroup    http://data.europa.eu/esco/isced-f/00
# 1  SkillGroup   http://data.europa.eu/esco/isced-f/000
# 2  SkillGroup  http://data.europa.eu/esco/isced-f/0000
# 3  SkillGroup   http://data.europa.eu/esco/isced-f/001
# 4  SkillGroup  http://data.europa.eu/esco/isced-f/0011
#
#                                       preferredLabel altLabels hiddenLabels  \
# 0              generic programmes and qualifications       NaN          NaN
# 1  generic programmes and qualifications not furt...       NaN          NaN
# 2  generic programmes and qualifications not furt...       NaN          NaN
# 3                basic programmes and qualifications       NaN          NaN
# 4                basic programmes and qualifications       NaN          NaN
#
#      status              modifiedDate scopeNote  \
# 0  released                       NaN       NaN
# 1  released  2023-07-13T15:16:44.968Z       NaN
# ...

# %%
df.describe()
# Out:
#        conceptType                                         conceptUri  \
# count          640                                                640
# unique           1                                                640
# top     SkillGroup  http://data.europa.eu/esco/skill/f5328159-dfe9...
# freq           640                                                  1
#
#                                      preferredLabel                 altLabels  \
# count                                           640                       112
# unique                                          518                        70
# top     communication, collaboration and creativity  working with information
# freq                                              3                         3
#
#                                              hiddenLabels    status  \
# count                                                  17       636
# unique                                                 17         1
# ...

# %%
##Handling missing values 
df.isnull().any(axis=1)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 635    True
# 636    True
# 637    True
# 638    True
# 639    True
# Length: 640, dtype: bool

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Major_Category                0
# Year_of_Study                 0
# Pre_Semester_GPA              0
# Weekly_GenAI_Hours            0
# Primary_Use_Case              0
# Prompt_Engineering_Skill      0
# Tool_Diversity                0
# Paid_Subscription             0
# Traditional_Study_Hours       0
# Perceived_AI_Dependency       0
# Institutional_Policy          0
# Anxiety_Level_During_Exams    0
# Post_Semester_GPA             0
# Skill_Retention_Score         0
# Burnout_Risk_Level            0
# dtype: int64

# %%
df_fillna=df.fillna(0)

# %%
##Filling missing value with the mean of the cloumn
##For sales report the Sales column has missing values which are replaced by the mean 
##df['Sales_fillna']=df['Sales'].fillna(df['Sales'].mean())

# %%
df.dtypes
# Out:
# conceptType       object
# conceptUri        object
# preferredLabel    object
# altLabels         object
# hiddenLabels      object
# status            object
# modifiedDate      object
# scopeNote         object
# inScheme          object
# description       object
# code              object
# dtype: object

# %%
##Renaming columns
df.rename(columns={'conceptType':'conceptTypes'})
# Out:
#     conceptTypes                                         conceptUri  \
# 0     SkillGroup              http://data.europa.eu/esco/isced-f/00
# 1     SkillGroup             http://data.europa.eu/esco/isced-f/000
# 2     SkillGroup            http://data.europa.eu/esco/isced-f/0000
# 3     SkillGroup             http://data.europa.eu/esco/isced-f/001
# 4     SkillGroup            http://data.europa.eu/esco/isced-f/0011
# ..           ...                                                ...
# 635   SkillGroup  http://data.europa.eu/esco/skill/fbb861f7-2386...
# 636   SkillGroup  http://data.europa.eu/esco/skill/fe317a4c-e4e0...
# 637   SkillGroup  http://data.europa.eu/esco/skill/fe5eabaa-63f6...
# 638   SkillGroup  http://data.europa.eu/esco/skill/ff565308-8f29...
# 639   SkillGroup  http://data.europa.eu/esco/skill/fff1d675-c36a...
#
#                                         preferredLabel  \
# 0                generic programmes and qualifications
# ...

# %%
##Chnage the datatype
##df[new_column_name']=df['column_name'].astype(the datatype in which we want to convert)

# %%
## Data Aggregating and grouping
##grouped_mean=df.groupby('column_name')['column_name_1'].mean() groupby one column and aggregate from same column or diff
##grouped_sum=df.groupby('column_name',column_name2)['column_name_1'].sum() groupby two column and aggregate from same column or diff
##grouped_agg=df.groupby('column_name',column_name2)['column_name_1'].agg['mean','sum','count'] groupby one column and use all aggregate function for the same column or diff

# %%
##Merging and joining the dataframes 
df1=pd.DataFrame({'Key':['A','B','C'], 'Values':[1,2,3]})
df2=pd.DataFrame({'Key':['A','B','D'], 'Values':[4,5,6]})

# %%
df1
# Out:
#   Key  Values
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Values
# 0   A       4
# 1   B       5
# 2   D       6

# %%
##Merge the Dataframe on the key column
pd.merge(df1,df2,on='Key',how='inner')
# Out:
#   Key  Values_x  Values_y
# 0   A         1         4
# 1   B         2         5

# %%
pd.merge(df1,df2,on='Key',how='outer')
# Out:
#   Key  Values_x  Values_y
# 0   A       1.0       4.0
# 1   B       2.0       5.0
# 2   C       3.0       NaN
# 3   D       NaN       6.0

# %%
pd.merge(df1,df2,on='Key',how='left')
# Out:
#   Key  Values_x  Values_y
# 0   A         1       4.0
# 1   B         2       5.0
# 2   C         3       NaN

# %%
pd.merge(df1,df2,on='Key',how='right')
# Out:
#   Key  Values_x  Values_y
# 0   A       1.0         4
# 1   B       2.0         5
# 2   D       NaN         6
